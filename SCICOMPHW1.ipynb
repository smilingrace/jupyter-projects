# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/births/US_births_2000-2014_SSA.csv')
df
# Out:
#       year  month  date_of_month  day_of_week  births
# 0     2000      1              1            6    9083
# 1     2000      1              2            7    8006
# 2     2000      1              3            1   11363
# 3     2000      1              4            2   13032
# 4     2000      1              5            3   12558
# ...    ...    ...            ...          ...     ...
# 5474  2014     12             27            6    8656
# 5475  2014     12             28            7    7724
# 5476  2014     12             29            1   12811
# 5477  2014     12             30            2   13634
# 5478  2014     12             31            3   11990
#
# [5479 rows x 5 columns]

# %%
import openpyxl 

wb = openpyxl.load_workbook('tmdb_5000_credits.csv')
# Out:
# ---------------------------------------------------------------------------
# InvalidFileException                      Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 import openpyxl
# ----> 3 wb = openpyxl.load_workbook('tmdb_5000_credits.csv')
#
# File ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py:315, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     288 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     289                   data_only=False, keep_links=True):
#     290     """Open the given filename and return the workbook
#     291
#     292     :param filename: the path to open or a file-like object
#    (...)
#     313
#     314     """
# --> 315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
#     317     reader.read()
#     318     return reader.wb
#
# ...

# %%
df=pd.read_csv('https://github.com/oregonstate-physics/hw1-birth-rates-smilingrace.git')
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 df=pd.read_csv('https://github.com/oregonstate-physics/hw1-birth-rates-smilingrace.git')
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

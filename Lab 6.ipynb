# %%
import numpy as np
from matplotlib import pyplot as plt
import math


I=np.array([0.1369, 0.0682, 0.442, 0.974, 1.699, 2.806, 3.65])
O=np.array([0.139, 0.0694, 0.443, 0.976, 1.701, 2.808, 3.65])

plt.plot(I, O)
plt.xlabel("Voltage Input")          
plt.ylabel("Voltage Output")
plt.title("Input vs Output Voltage")
# Out:
# Text(0.5, 1.0, 'Input vs Output Voltage')

# %%
import matplotlib.pyplot as plt
import numpy as np

M1=np.arange(0,10000,1)
M2=600
Mu=(M1*M2)/(M1+M2)
plt.plot(Mu)

# %%
M2=np.arange(0,10000,1)
M1=600
Mu=(M1*M2)/(M1+M2)
plt.plot(Mu)

# %%
M1=np.arange(0,10000,1)
M2=10000
Mu=(M1*M2)/(M1+M2)
plt.plot(Mu)

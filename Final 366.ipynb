# %%
import numpy as np
import matplotlib.pyplot as plt

k = 1/(4*np.pi*8.854e-12)  # Coulomb's constant
q = 1.6e-19  # Charge of each particle
r = 1  # Radius of the sphere
N = 7  # Number of points to plot

def potential(x, y, z):
    dist = np.sqrt(x**2 + y**2 + z**2)

X, Y, Z = np.meshgrid(np.linspace(-r, r, N), np.linspace(-r, r, N), np.linspace(-r, r, N), indexing='ij')
r_vals = np.sqrt(X**2 + Y**2 + Z**2)

plt.plot(r_vals.flatten(), V_single, label='Single charge potential')
plt.xlabel('Distance from origin')
plt.ylabel('Potential')
plt.legend()
plt.show()
